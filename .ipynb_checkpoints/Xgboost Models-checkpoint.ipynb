# %%
#XGboost Only:
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
#plt.style.use('fivethirtyeight')
#import imageio
import os

# %%
df=pd.read_csv("mid-gas-2017-2019.csv",index_col=[0], parse_dates=[0])
df.head(3)
# Out:
#                      Price  Volume  Settlement Period  hour dayofweek  \
# datetime
# 2017-01-01 00:00:00  44.90  505.00                  1   0.0       Sun
# 2017-01-01 00:30:00  47.13  559.15                  2   0.0       Sun
# 2017-01-01 01:00:00  45.62  649.35                  3   1.0       Sun
#
#                      quarter month    year  dayofyear  dayofmonth  weekofyear  \
# datetime
# 2017-01-01 00:00:00      1.0   Jan  2017.0        1.0         1.0        52.0
# 2017-01-01 00:30:00      1.0   Jan  2017.0        1.0         1.0        52.0
# 2017-01-01 01:00:00      1.0   Jan  2017.0        1.0         1.0        52.0
#
#                        SAP    EU_ETS        Gas
# datetime
# 2017-01-01 00:00:00  16.95  1.033832  21.294832
# 2017-01-01 00:30:00  16.95  1.033832  21.294832
# 2017-01-01 01:00:00  16.95  1.033832  21.294832

# %%
df_INDO=pd.read_csv('INDO-2017-2019.csv',index_col=[0],parse_dates=[0])
df_INDO.head(3)
# Out:
#                      Settlement_Period   INDO
# datetime
# 2017-01-01 00:00:00                  1  27239
# 2017-01-01 00:30:00                  2  27814
# 2017-01-01 01:00:00                  3  27453

# %%
df=pd.merge(df,df_INDO['INDO'], how='inner', left_index=True, right_index=True)

# %%
df.head(3)
# Out:
#                      Price  Volume  Settlement Period  hour dayofweek  \
# datetime
# 2017-01-01 00:00:00  44.90  505.00                  1   0.0       Sun
# 2017-01-01 00:30:00  47.13  559.15                  2   0.0       Sun
# 2017-01-01 01:00:00  45.62  649.35                  3   1.0       Sun
#
#                      quarter month    year  dayofyear  dayofmonth  weekofyear  \
# datetime
# 2017-01-01 00:00:00      1.0   Jan  2017.0        1.0         1.0        52.0
# 2017-01-01 00:30:00      1.0   Jan  2017.0        1.0         1.0        52.0
# 2017-01-01 01:00:00      1.0   Jan  2017.0        1.0         1.0        52.0
#
#                        SAP    EU_ETS        Gas   INDO
# datetime
# 2017-01-01 00:00:00  16.95  1.033832  21.294832  27239
# 2017-01-01 00:30:00  16.95  1.033832  21.294832  27814
# 2017-01-01 01:00:00  16.95  1.033832  21.294832  27453

# %%
#Splitting the data:
def split_data(data, split_date):
    return data[data.index <= split_date].copy(), \
           data[data.index >  split_date].copy()

def limit(data, frm, to):
    return data[(data.index>=frm)&(data.index<to)]

# %%
df.sort_index(inplace=True)

# %%
t = df.Price.copy()
t = t.drop(t.index[t.index.duplicated()])
freq_index = pd.date_range(start=t.index[0], end=t.index[-1], freq='30T')
constructed = pd.Series(index=freq_index, name='Price')
constructed.update(t)
constructed.interpolate(inplace=True)

# %%
train = limit(constructed, '2017-01-01', '2019-06-15')
test  = limit(constructed, '2019-06-15', '2019-07-01')
train.shape, test.shape
# Out:
# ((42960,), (768,))

# %%
#for INDO data
i = df.INDO.copy()
i = i.drop(i.index[i.index.duplicated()])
freq_index = pd.date_range(start=i.index[0], end=i.index[-1], freq='30T')
constructed_i = pd.Series(index=freq_index, name='INDO')
constructed_i.update(i)
constructed_i.interpolate(inplace=True)

# %%
train_indo = limit(constructed_i, '2019-01-01', '2019-06-15')
test_indo  = limit(constructed_i, '2019-06-15', '2019-07-01')
print(train_indo.shape)
print(test_indo.shape)
# Out:
# (7920,)
# (768,)

# %%
df_train=df[df.index.isin(train.index)].copy()
df_test=df[df.index.isin(test.index)].copy()
df_train.shape,df_test.shape
# Out:
# ((42575, 15), (768, 15))

# %%
#split_date = '15-Jun-2019 00:00'
#df_train = df.loc[df.index <= split_date].copy()
#df_test = df.loc[df.index > split_date].copy()

# %%
plt.figure(figsize=(15,5))
plt.xlabel('time')
plt.ylabel('electricity prices')
plt.plot(train.index,train)
plt.plot(test.index,test)
plt.show()

# %%
def create_features(df):
    """
    Creates time series features from datetime index
    """
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear', 'Gas', 'INDO']]
    
    return X

# %%
X_train, y_train = create_features(df_train), df_train['Price']
X_test, y_test   = create_features(df_test), df_test['Price']

X_train.shape, y_train.shape, X_test.shape,y_test.shape
# Out:
# ((42575, 10), (42575,), (768, 10), (768,))

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50, #stop if 50 consequent rounds without decrease of error
        verbose=False) # Change verbose to True if you want to see it train
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb.plot_importance(reg, height=0.9)

# %%
forecast_xgb= reg.predict(X_test)

# %%
plt.figure(figsize=(16,8))
plt.plot(pd.concat([train,test]))
plt.plot(test.index, forecast_xgb, label='XGBoost')
plt.legend()

# %%
plt.figure(figsize=(18,6))
#plt.plot(pd.concat([train,test]))
plt.plot(test, label = 'Actual electricity prices from test setActual electricity prices from test set')
plt.plot(test.index,forecast_xgb, label='XGBoost Price Predictions')
plt.legend()
plot = plt.title('Half Hourly Price Predictions')

# %%
import pandas as pd

# %%
data = {'dt':df_test.index, 'predictions':forecast_xgb}

# %%
data=pd.DataFrame(data)
data
# Out:
#                      dt  predictions
# 0   2019-06-15 00:00:00    41.259491
# 1   2019-06-15 00:30:00    39.816010
# 2   2019-06-15 01:00:00    39.816010
# 3   2019-06-15 01:30:00    39.816010
# 4   2019-06-15 02:00:00    37.842598
# ..                  ...          ...
# 763 2019-06-30 21:30:00    41.576031
# 764 2019-06-30 22:00:00    41.576031
# 765 2019-06-30 22:30:00    35.671211
# 766 2019-06-30 23:00:00    39.453667
# 767 2019-06-30 23:30:00    32.731838
#
# [768 rows x 2 columns]

# %%
#data.to_csv('XGBoost-pred.csv')

# %%
data = pd.read_csv('XGBoost-pred.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data.head()
# Out:
#                     dt  predictions
# 0  2019-06-15 00:00:00    41.259490
# 1  2019-06-15 00:30:00    39.816010
# 2  2019-06-15 01:00:00    39.816010
# 3  2019-06-15 01:30:00    39.816010
# 4  2019-06-15 02:00:00    37.842598

# %%
xgb_pred=data.set_index('dt').predictions

# %%
xgb_pred
# Out:
# dt
# 2019-06-15 00:00:00    41.259490
# 2019-06-15 00:30:00    39.816010
# 2019-06-15 01:00:00    39.816010
# 2019-06-15 01:30:00    39.816010
# 2019-06-15 02:00:00    37.842598
#                          ...
# 2019-06-30 21:30:00    41.576030
# 2019-06-30 22:00:00    41.576030
# 2019-06-30 22:30:00    35.671210
# 2019-06-30 23:00:00    39.453667
# 2019-06-30 23:30:00    32.731840
# Name: predictions, Length: 768, dtype: float64

# %%
title = 'Half Hourly Price Predictions'
ylabel='Price'
xlabel='' 
ax = test.rename('Actual electricity prices from test set').plot(legend=True,figsize=(12,6),title=title)
xgb_pred.rename('XGBoost Model Predictions').plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);
# Out:
# 19 14:00', 'T'), Period('2019-06-19 14:30', 'T'),
#        Period('2019-06-19 15:00', 'T'), Period('2019-06-19 15:30', 'T'),
#        Period('2019-06-19 16:00', 'T'), Period('2019-06-19 16:30', 'T'),
#        Period('2019-06-19 17:00', 'T'), Period('2019-06-19 17:30', 'T'),
#        Period('2019-06-19 18:00', 'T'), Period('2019-06-19 18:30', 'T'),
#        Period('2019-06-19 19:00', 'T'), Period('2019-06-19 19:30', 'T'),
#        Period('2019-06-19 20:00', 'T'), Period('2019-06-19 20:30', 'T'),
#        Period('2019-06-19 21:00', 'T'), Period('2019-06-19 21:30', 'T'),
#        Period('2019-06-19 22:00', 'T'), Period('2019-06-19 22:30', 'T'),
#        Period('2019-06-19 23:00', 'T'), Period('2019-06-19 23:30', 'T'),
#        Period('2019-06-20 00:00', 'T'), Period('2019-06-20 00:30', 'T'),
#        Period('2019-06-20 01:00', 'T'), Period('2019-06-20 01:30', 'T'),
#        Period('2019-06-20 02:00', 'T'), Period('2019-06-20 02:30', 'T'),
#        Period('2019-06-20 03:00', 'T'), Period('2019-06-20 03:30', 'T'),
#        Period('2019-06-20 04:00', 'T'), Period('2019-06-20 04:30', 'T'),
#        Period('2019-06-20 05:00', 'T'), Period('2019-06-20 05:30', 'T'),
#        Period('2019-06-20 06:00', 'T'), Period('2019-06-20 06:30', 'T'),
#        Period('2019-06-20 07:00', 'T'), Period('2019-06-20 07:30', 'T'),
#        Period('2019-06-20 08:00', 'T'), Period('2019-06-20 08:30', 'T'),
#        Period('2019-06-20 09:00', 'T'), Period('2019-06-20 09:30', 'T'),
#        Period('2019-06-20 10:00', 'T'), Period('2019-06-20 10:30', 'T'),
#        Period('2019-06-20 11:00', 'T'), Period('2019-06-20 11:30', 'T'),
#        Period('2019-06-20 12:00', 'T'), Period('2019-06-20 12:30', 'T'),
#        Period('2019-06-20 13:00', 'T'), Period('2019-06-20 13:30', 'T'),
#        Period('2019-06-20 14:00', 'T'), Period('2019-06-20 14:30', 'T'),
#        Period('2019-06-20 15:00', 'T'), Period('2019-06-20 15:30', 'T'),
#        Period('2019-06-20 16:00', 'T'), Period('2019-06-20 16:30', 'T'),
#        Period('2019-06-20 17:00', 'T'), Period('2019-06-20 17:30', 'T'),
#        Period('2019-06-20 18:00', 'T'), Period('2019-06-20 18:30', 'T'),
#        Period('2019-06-20 19:00', 'T'), Period('2019-06-20 19:30', 'T'),
#        Period('2019-06-20 20:00', 'T'), Period('2019-06-20 20:30', 'T'),
#        Period('2019-06-20 21:00', 'T'), Period('2019-06-20 21:30', 'T'),
#        Period('2019-06-20 22:00', 'T'), Period('2019-06-20 22:30', 'T'),
#        Period('2019-06-20 23:00', 'T'), Period('2019-06-20 23:30', 'T'),
#        Period('2019-06-21 00:00', 'T'), Period('2019-06-21 00:30', 'T'),
#        Period('2019-06-21 01:00', 'T'), Period('2019-06-21 01:30', 'T'),
#        Period('2019-06-21 02:00', 'T'), Period('2019-06-21 02:30', 'T'),
#        Period('2019-06-21 03:00', 'T'), Period('2019-06-21 03:30', 'T'),
#        Period('2019-06-21 04:00', 'T'), Period('2019-06-21 04:30', 'T'),
#        Period('2019-06-21 05:00', 'T'), Period('2019-06-21 05:30', 'T'),
#        Period('2019-06-21 06:00', 'T'), Period('2019-06-21 06:30', 'T'),
#        Period('2019-06-21 07:00', 'T'), Period('2019-06-21 07:30', 'T'),
#        Period('2019-06-21 08:00', 'T'), Period('2019-06-21 08:30', 'T'),
#        Period('2019-06-21 09:00', 'T'), Period('2019-06-21 09:30', 'T'),
#        Period('2019-06-21 10:00', 'T'), Period('2019-06-21 10:30', 'T'),
#        Period('2019-06-21 11:00', 'T'), Period('2019-06-21 11:30', 'T'),
#        Period('2019-06-21 12:00', 'T'), Period('2019-06-21 12:30', 'T'),
#        Period('2019-06-21 13:00', 'T'), Period('2019-06-21 13:30', 'T'),
#        Period('2019-06-21 14:00', 'T'), Period('2019-06-21 14:30', 'T'),
#        Period('2019-06-21 15:00', 'T'), Period('2019-06-21 15:30', 'T'),
#        Period('2019-06-21 16:00', 'T'), Period('2019-06-21 16:30', 'T'),
#        Period('2019-06-21 17:00', 'T'), Period('2019-06-21 17:30', 'T'),
#        Period('2019-06-21 18:00', 'T'), Period('2019-06-21 18:30', 'T'),
#        Period('2019-06-21 19:00', 'T'), Period('2019-06-21 19:30', 'T'),
#        Period('2019-06-21 20:00', 'T'), Period('2019-06-21 20:30', 'T'),
#        Period('2019-06-21 21:00', 'T'), Period('2019-06-21 21:30', 'T'),
#        Period('2019-06-21 22:00', 'T'), Period('2019-06-21 22:30', 'T'),
#        Period('2019-06-21 23:00', 'T'), Period('2019-06-21 23:30', 'T'),
#        Period('2019-06-22 00:00', 'T'), Period('2019-06-22 00:30', 'T'),
#        Period('2019-06-22 01:00', 'T'), Period('2019-06-22 01:30', 'T'),
#        Period('2019-06-22 02:00', 'T'), Period('2019-06-22 02:30', 'T'),
#        Period('2019-06-22 03:00', 'T'), Period('2019-06-22 03:30', 'T'),
#        Period('2019-06-22 04:00', 'T'), Period('2019-06-22 04:30', 'T'),
#        Period('2019-06-22 05:00', 'T'), Period('2019-06-22 05:30', 'T'),
#        Period('2019-06-22 06:00', 'T'), Period('2019-06-22 06:30', 'T'),
#        Period('2019-06-22 07:00', 'T'), Period('2019-06-22 07:30', 'T'),
#        Period('2019-06-22 08:00', 'T'), Period('2019-06-22 08:30', 'T'),
#        Period('2019-06-22 09:00', 'T'), Period('2019-06-22 09:30', 'T'),
#        Period('2019-06-22 10:00', 'T'), Period('2019-06-22 10:30', 'T'),
#        Period('2019-06-22 11:00', 'T'), Period('2019-06-22 11:30', 'T'),
#        Period('2019-06-22 12:00', 'T'), Period('2019-06-22 12:30', 'T'),
#        Period('2019-06-22 13:00', 'T'), Period('2019-06-22 13:30', 'T'),
#        Period('2019-06-22 14:00', 'T'), Period('2019-06-22 14:30', 'T'),
#        Period('2019-06-22 15:00', 'T'), Period('2019-06-22 15:30', 'T'),
#        Period('2019-06-22 16:00', 'T'), Period('2019-06-22 16:30', 'T'),
#        Period('2019-06-22 17:00', 'T'), Period('2019-06-22 17:30', 'T'),
#        Period('2019-06-22 18:00', 'T'), Period('2019-06-22 18:30', 'T'),
#        Period('2019-06-22 19:00', 'T'), Period('2019-06-22 19:30', 'T'),
#        Period('2019-06-22 20:00', 'T'), Period('2019-06-22 20:30', 'T'),
#        Period('2019-06-22 21:00', 'T'), Period('2019-06-22 21:30', 'T'),
#        Period('2019-06-22 22:00', 'T'), Period('2019-06-22 22:30', 'T'),
#        Period('2019-06-22 23:00', 'T'), Period('2019-06-22 23:30', 'T'),
#        Period('2019-06-23 00:00', 'T'), Period('2019-06-23 00:30', 'T'),
#        Period('2019-06-23 01:00', 'T'), Period('2019-06-23 01:30', 'T'),
#        Period('2019-06-23 02:00', 'T'), Period('2019-06-23 02:30', 'T'),
#        Period('2019-06-23 03:00', 'T'), Period('2019-06-23 03:30', 'T'),
#        Period('2019-06-23 04:00', 'T'), Period('2019-06-23 04:30', 'T'),
#        Period('2019-06-23 05:00', 'T'), Period('2019-06-23 05:30', 'T'),
#        Period('2019-06-23 06:00', 'T'), Period('2019-06-23 06:30', 'T'),
#        Period('2019-06-23 07:00', 'T'), Period('2019-06-23 07:30', 'T'),
#        Period('2019-06-23 08:00', 'T'), Period('2019-06-23 08:30', 'T'),
#        Period('2019-06-23 09:00', 'T'), Period('2019-06-23 09:30', 'T'),
#        Period('2019-06-23 10:00', 'T'), Period('2019-06-23 10:30', 'T'),
#        Period('2019-06-23 11:00', 'T'), Period('2019-06-23 11:30', 'T'),
#        Period('2019-06-23 12:00', 'T'), Period('2019-06-23 12:30', 'T'),
#        Period('2019-06-23 13:00', 'T'), Period('2019-06-23 13:30', 'T'),
#        Period('2019-06-23 14:00', 'T'), Period('2019-06-23 14:30', 'T'),
#        Period('2019-06-23 15:00', 'T'), Period('2019-06-23 15:30', 'T'),
#        Period('2019-06-23 16:00', 'T'), Period('2019-06-23 16:30', 'T'),
#        Period('2019-06-23 17:00', 'T'), Period('2019-06-23 17:30', 'T'),
#        Period('2019-06-23 18:00', 'T'), Period('2019-06-23 18:30', 'T'),
#        Period('2019-06-23 19:00', 'T'), Period('2019-06-23 19:30', 'T'),
#        Period('2019-06-23 20:00', 'T'), Period('2019-06-23 20:30', 'T'),
#        Period('2019-06-23 21:00', 'T'), Period('2019-06-23 21:30', 'T'),
#        Period('2019-06-23 22:00', 'T'), Period('2019-06-23 22:30', 'T'),
#        Period('2019-06-23 23:00', 'T'), Period('2019-06-23 23:30', 'T'),
#        Period('2019-06-24 00:00', 'T'), Period('2019-06-24 00:30', 'T'),
#        Period('2019-06-24 01:00', 'T'), Period('2019-06-24 01:30', 'T'),
#        Period('2019-06-24 02:00', 'T'), Period('2019-06-24 02:30', 'T'),
#        Period('2019-06-24 03:00', 'T'), Period('2019-06-24 03:30', 'T'),
#        Period('2019-06-24 04:00', 'T'), Period('2019-06-24 04:30', 'T'),
#        Period('2019-06-24 05:00', 'T'), Period('2019-06-24 05:30', 'T'),
#        Period('2019-06-24 06:00', 'T'), Period('2019-06-24 06:30', 'T'),
#        Period('2019-06-24 07:00', 'T'), Period('2019-06-24 07:30', 'T'),
#        Period('2019-06-24 08:00', 'T'), Period('2019-06-24 08:30', 'T'),
#        Period('2019-06-24 09:00', 'T'), Period('2019-06-24 09:30', 'T'),
#        Period('2019-06-24 10:00', 'T'), Period('2019-06-24 10:30', 'T'),
#        Period('2019-06-24 11:00', 'T'), Period('2019-06-24 11:30', 'T'),
#        Period('2019-06-24 12:00', 'T'), Period('2019-06-24 12:30', 'T'),
#        Period('2019-06-24 13:00', 'T'), Period('2019-06-24 13:30', 'T'),
#        Period('2019-06-24 14:00', 'T'), Period('2019-06-24 14:30', 'T'),
#        Period('2019-06-24 15:00', 'T'), Period('2019-06-24 15:30', 'T'),
#        Period('2019-06-24 16:00', 'T'), Period('2019-06-24 16:30', 'T'),
#        Period('2019-06-24 17:00', 'T'), Period('2019-06-24 17:30', 'T'),
#        Period('2019-06-24 18:00', 'T'), Period('2019-06-24 18:30', 'T'),
#        Period('2019-06-24 19:00', 'T'), Period('2019-06-24 19:30', 'T'),
#        Period('2019-06-24 20:00', 'T'), Period('2019-06-24 20:30', 'T'),
#        Period('2019-06-24 21:00', 'T'), Period('2019-06-24 21:30', 'T'),
#        Period('2019-06-24 22:00', 'T'), Period('2019-06-24 22:30', 'T'),
#        Period('2019-06-24 23:00', 'T'), Period('2019-06-24 23:30', 'T'),
#        Period('2019-06-25 00:00', 'T'), Period('2019-06-25 00:30', 'T'),
#        Period('2019-06-25 01:00', 'T'), Period('2019-06-25 01:30', 'T'),
#        Period('2019-06-25 02:00', 'T'), Period('2019-06-25 02:30', 'T'),
#        Period('2019-06-25 03:00', 'T'), Period('2019-06-25 03:30', 'T'),
#        Period('2019-06-25 04:00', 'T'), Period('2019-06-25 04:30', 'T'),
#        Period('2019-06-25 05:00', 'T'), Period('2019-06-25 05:30', 'T'),
#        Period('2019-06-25 06:00', 'T'), Period('2019-06-25 06:30', 'T'),
#        Period('2019-06-25 07:00', 'T'), Period('2019-06-25 07:30', 'T'),
#        Period('2019-06-25 08:00', 'T'), Period('2019-06-25 08:30', 'T'),
#        Period('2019-06-25 09:00', 'T'), Period('2019-06-25 09:30', 'T'),
#        Period('2019-06-25 10:00', 'T'), Period('2019-06-25 10:30', 'T'),
#        Period('2019-06-25 11:00', 'T'), Period('2019-06-25 11:30', 'T'),
#        Period('2019-06-25 12:00', 'T'), Period('2019-06-25 12:30', 'T'),
#        Period('2019-06-25 13:00', 'T'), Period('2019-06-25 13:30', 'T'),
#        Period('2019-06-25 14:00', 'T'), Period('2019-06-25 14:30', 'T'),
#        Period('2019-06-25 15:00', 'T'), Period('2019-06-25 15:30', 'T'),
#        Period('2019-06-25 16:00', 'T'), Period('2019-06-25 16:30', 'T'),
#        Period('2019-06-25 17:00', 'T'), Period('2019-06-25 17:30', 'T'),
#        Period('2019-06-25 18:00', 'T'), Period('2019-06-25 18:30', 'T'),
#        Period('2019-06-25 19:00', 'T'), Period('2019-06-25 19:30', 'T'),
#        Period('2019-06-25 20:00', 'T'), Period('2019-06-25 20:30', 'T'),
#        Period('2019-06-25 21:00', 'T'), Period('2019-06-25 21:30', 'T'),
#        Period('2019-06-25 22:00', 'T'), Period('2019-06-25 22:30', 'T'),
#        Period('2019-06-25 23:00', 'T'), Period('2019-06-25 23:30', 'T'),
#        Period('2019-06-26 00:00', 'T'), Period('2019-06-26 00:30', 'T'),
#        Period('2019-06-26 01:00', 'T'), Period('2019-06-26 01:30', 'T'),
#        Period('2019-06-26 02:00', 'T'), Period('2019-06-26 02:30', 'T'),
#        Period('2019-06-26 03:00', 'T'), Period('2019-06-26 03:30', 'T'),
#        Period('2019-06-26 04:00', 'T'), Period('2019-06-26 04:30', 'T'),
#        Period('2019-06-26 05:00', 'T'), Period('2019-06-26 05:30', 'T'),
#        Period('2019-06-26 06:00', 'T'), Period('2019-06-26 06:30', 'T'),
#        Period('2019-06-26 07:00', 'T'), Period('2019-06-26 07:30', 'T'),
#        Period('2019-06-26 08:00', 'T'), Period('2019-06-26 08:30', 'T'),
#        Period('2019-06-26 09:00', 'T'), Period('2019-06-26 09:30', 'T'),
#        Period('2019-06-26 10:00', 'T'), Period('2019-06-26 10:30', 'T'),
#        Period('2019-06-26 11:00', 'T'), Period('2019-06-26 11:30', 'T'),
#        Period('2019-06-26 12:00', 'T'), Period('2019-06-26 12:30', 'T'),
#        Period('2019-06-26 13:00', 'T'), Period('2019-06-26 13:30', 'T'),
#        Period('2019-06-26 14:00', 'T'), Period('2019-06-26 14:30', 'T'),
#        Period('2019-06-26 15:00', 'T'), Period('2019-06-26 15:30', 'T'),
#        Period('2019-06-26 16:00', 'T'), Period('2019-06-26 16:30', 'T'),
#        Period('2019-06-26 17:00', 'T'), Period('2019-06-26 17:30', 'T'),
#        Period('2019-06-26 18:00', 'T'), Period('2019-06-26 18:30', 'T'),
#        Period('2019-06-26 19:00', 'T'), Period('2019-06-26 19:30', 'T'),
#        Period('2019-06-26 20:00', 'T'), Period('2019-06-26 20:30', 'T'),
#        Period('2019-06-26 21:00', 'T'), Period('2019-06-26 21:30', 'T'),
#        Period('2019-06-26 22:00', 'T'), Period('2019-06-26 22:30', 'T'),
#        Period('2019-06-26 23:00', 'T'), Period('2019-06-26 23:30', 'T'),
#        Period('2019-06-27 00:00', 'T'), Period('2019-06-27 00:30', 'T'),
#        Period('2019-06-27 01:00', 'T'), Period('2019-06-27 01:30', 'T'),
#        Period('2019-06-27 02:00', 'T'), Period('2019-06-27 02:30', 'T'),
#        Period('2019-06-27 03:00', 'T'), Period('2019-06-27 03:30', 'T'),
#        Period('2019-06-27 04:00', 'T'), Period('2019-06-27 04:30', 'T'),
#        Period('2019-06-27 05:00', 'T'), Period('2019-06-27 05:30', 'T'),
#        Period('2019-06-27 06:00', 'T'), Period('2019-06-27 06:30', 'T'),
#        Period('2019-06-27 07:00', 'T'), Period('2019-06-27 07:30', 'T'),
#        Period('2019-06-27 08:00', 'T'), Period('2019-06-27 08:30', 'T'),
#        Period('2019-06-27 09:00', 'T'), Period('2019-06-27 09:30', 'T'),
#        Period('2019-06-27 10:00', 'T'), Period('2019-06-27 10:30', 'T'),
#        Period('2019-06-27 11:00', 'T'), Period('2019-06-27 11:30', 'T'),
#        Period('2019-06-27 12:00', 'T'), Period('2019-06-27 12:30', 'T'),
#        Period('2019-06-27 13:00', 'T'), Period('2019-06-27 13:30', 'T'),
#        Period('2019-06-27 14:00', 'T'), Period('2019-06-27 14:30', 'T'),
#        Period('2019-06-27 15:00', 'T'), Period('2019-06-27 15:30', 'T'),
#        Period('2019-06-27 16:00', 'T'), Period('2019-06-27 16:30', 'T'),
#        Period('2019-06-27 17:00', 'T'), Period('2019-06-27 17:30', 'T'),
#        Period('2019-06-27 18:00', 'T'), Period('2019-06-27 18:30', 'T'),
#        Period('2019-06-27 19:00', 'T'), Period('2019-06-27 19:30', 'T'),
#        Period('2019-06-27 20:00', 'T'), Period('2019-06-27 20:30', 'T'),
#        Period('2019-06-27 21:00', 'T'), Period('2019-06-27 21:30', 'T'),
#        Period('2019-06-27 22:00', 'T'), Period('2019-06-27 22:30', 'T'),
#        Period('2019-06-27 23:00', 'T'), Period('2019-06-27 23:30', 'T'),
#        Period('2019-06-28 00:00', 'T'), Period('2019-06-28 00:30', 'T'),
#        Period('2019-06-28 01:00', 'T'), Period('2019-06-28 01:30', 'T'),
#        Period('2019-06-28 02:00', 'T'), Period('2019-06-28 02:30', 'T'),
#        Period('2019-06-28 03:00', 'T'), Period('2019-06-28 03:30', 'T'),
#        Period('2019-06-28 04:00', 'T'), Period('2019-06-28 04:30', 'T'),
#        Period('2019-06-28 05:00', 'T'), Period('2019-06-28 05:30', 'T'),
#        Period('2019-06-28 06:00', 'T'), Period('2019-06-28 06:30', 'T'),
#        Period('2019-06-28 07:00', 'T'), Period('2019-06-28 07:30', 'T'),
#        Period('2019-06-28 08:00', 'T'), Period('2019-06-28 08:30', 'T'),
#        Period('2019-06-28 09:00', 'T'), Period('2019-06-28 09:30', 'T'),
#        Period('2019-06-28 10:00', 'T'), Period('2019-06-28 10:30', 'T'),
#        Period('2019-06-28 11:00', 'T'), Period('2019-06-28 11:30', 'T'),
#        Period('2019-06-28 12:00', 'T'), Period('2019-06-28 12:30', 'T'),
#        Period('2019-06-28 13:00', 'T'), Period('2019-06-28 13:30', 'T'),
#        Period('2019-06-28 14:00', 'T'), Period('2019-06-28 14:30', 'T'),
#        Period('2019-06-28 15:00', 'T'), Period('2019-06-28 15:30', 'T'),
#        Period('2019-06-28 16:00', 'T'), Period('2019-06-28 16:30', 'T'),
#        Period('2019-06-28 17:00', 'T'), Period('2019-06-28 17:30', 'T'),
#        Period('2019-06-28 18:00', 'T'), Period('2019-06-28 18:30', 'T'),
#        Period('2019-06-28 19:00', 'T'), Period('2019-06-28 19:30', 'T'),
#        Period('2019-06-28 20:00', 'T'), Period('2019-06-28 20:30', 'T'),
#        Period('2019-06-28 21:00', 'T'), Period('2019-06-28 21:30', 'T'),
#        Period('2019-06-28 22:00', 'T'), Period('2019-06-28 22:30', 'T'),
#        Period('2019-06-28 23:00', 'T'), Period('2019-06-28 23:30', 'T'),
#        Period('2019-06-29 00:00', 'T'), Period('2019-06-29 00:30', 'T'),
#        Period('2019-06-29 01:00', 'T'), Period('2019-06-29 01:30', 'T'),
#        Period('2019-06-29 02:00', 'T'), Period('2019-06-29 02:30', 'T'),
#        Period('2019-06-29 03:00', 'T'), Period('2019-06-29 03:30', 'T'),
#        Period('2019-06-29 04:00', 'T'), Period('2019-06-29 04:30', 'T'),
#        Period('2019-06-29 05:00', 'T'), Period('2019-06-29 05:30', 'T'),
#        Period('2019-06-29 06:00', 'T'), Period('2019-06-29 06:30', 'T'),
#        Period('2019-06-29 07:00', 'T'), Period('2019-06-29 07:30', 'T'),
#        Period('2019-06-29 08:00', 'T'), Period('2019-06-29 08:30', 'T'),
#        Period('2019-06-29 09:00', 'T'), Period('2019-06-29 09:30', 'T'),
#        Period('2019-06-29 10:00', 'T'), Period('2019-06-29 10:30', 'T'),
#        Period('2019-06-29 11:00', 'T'), Period('2019-06-29 11:30', 'T'),
#        Period('2019-06-29 12:00', 'T'), Period('2019-06-29 12:30', 'T'),
#        Period('2019-06-29 13:00', 'T'), Period('2019-06-29 13:30', 'T'),
#        Period('2019-06-29 14:00', 'T'), Period('2019-06-29 14:30', 'T'),
#        Period('2019-06-29 15:00', 'T'), Period('2019-06-29 15:30', 'T'),
#        Period('2019-06-29 16:00', 'T'), Period('2019-06-29 16:30', 'T'),
#        Period('2019-06-29 17:00', 'T'), Period('2019-06-29 17:30', 'T'),
#        Period('2019-06-29 18:00', 'T'), Period('2019-06-29 18:30', 'T'),
#        Period('2019-06-29 19:00', 'T'), Period('2019-06-29 19:30', 'T'),
#        Period('2019-06-29 20:00', 'T'), Period('2019-06-29 20:30', 'T'),
#        Period('2019-06-29 21:00', 'T'), Period('2019-06-29 21:30', 'T'),
#        Period('2019-06-29 22:00', 'T'), Period('2019-06-29 22:30', 'T'),
#        Period('2019-06-29 23:00', 'T'), Period('2019-06-29 23:30', 'T'),
#        Period('2019-06-30 00:00', 'T'), Period('2019-06-30 00:30', 'T'),
#        Period('2019-06-30 01:00', 'T'), Period('2019-06-30 01:30', 'T'),
#        Period('2019-06-30 02:00', 'T'), Period('2019-06-30 02:30', 'T'),
#        Period('2019-06-30 03:00', 'T'), Period('2019-06-30 03:30', 'T'),
#        Period('2019-06-30 04:00', 'T'), Period('2019-06-30 04:30', 'T'),
#        Period('2019-06-30 05:00', 'T'), Period('2019-06-30 05:30', 'T'),
#        Period('2019-06-30 06:00', 'T'), Period('2019-06-30 06:30', 'T'),
#        Period('2019-06-30 07:00', 'T'), Period('2019-06-30 07:30', 'T'),
#        Period('2019-06-30 08:00', 'T'), Period('2019-06-30 08:30', 'T'),
#        Period('2019-06-30 09:00', 'T'), Period('2019-06-30 09:30', 'T'),
#        Period('2019-06-30 10:00', 'T'), Period('2019-06-30 10:30', 'T'),
#        Period('2019-06-30 11:00', 'T'), Period('2019-06-30 11:30', 'T'),
#        Period('2019-06-30 12:00', 'T'), Period('2019-06-30 12:30', 'T'),
#        Period('2019-06-30 13:00', 'T'), Period('2019-06-30 13:30', 'T'),
#        Period('2019-06-30 14:00', 'T'), Period('2019-06-30 14:30', 'T'),
#        Period('2019-06-30 15:00', 'T'), Period('2019-06-30 15:30', 'T'),
#        Period('2019-06-30 16:00', 'T'), Period('2019-06-30 16:30', 'T'),
#        Period('2019-06-30 17:00', 'T'), Period('2019-06-30 17:30', 'T'),
#        Period('2019-06-30 18:00', 'T'), Period('2019-06-30 18:30', 'T'),
#        Period('2019-06-30 19:00', 'T'), Period('2019-06-30 19:30', 'T'),
#        Period('2019-06-30 20:00', 'T'), Period('2019-06-30 20:30', 'T'),
#        Period('2019-06-30 21:00', 'T'), Period('2019-06-30 21:30', 'T'),
#        Period('2019-06-30 22:00', 'T'), Period('2019-06-30 22:30', 'T'),
#        Period('2019-06-30 23:00', 'T'), Period('2019-06-30 23:30', 'T')],
#       dtype=object)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-03d335a69f94> in <module>
#       3 xlabel=''
#       4 ax = test.rename('Actual electricity prices from test set').plot(legend=True,figsize=(12,6),title=title)
# ----> 5 xgb_pred.rename('XGBoost Model Predictions').plot(legend=True)
#       6 ax.autoscale(axis='x',tight=True)
#       7 ax.set(xlabel=xlabel, ylabel=ylabel);
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1083                 stacking_id=stacking_id,
#    1084                 is_errorbar=is_errorbar,
# -> 1085                 **kwds,
#    1086             )
#    1087             self._add_legend_handle(newlines[0], label, index=i)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1130         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1131         # set date formatter, locators and rescale limits
# -> 1132         format_dateaxis(ax, ax.freq, data.index)
#    1133         return lines
#    1134
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/timeseries.py in format_dateaxis(subplot, freq, index)
#     307         subplot.xaxis.set_major_formatter(TimeSeries_TimedeltaFormatter())
#     308     else:
# --> 309         raise TypeError("index type not supported")
#     310
#     311     pylab.draw_if_interactive()
#
# TypeError: index type not supported

# %%
#Xgboost Model  evaluation:
from statsmodels.tools.eval_measures import mse,rmse
from sklearn.metrics import mean_absolute_error

error1 = mse(test, forecast_xgb)
error2 = rmse(test, forecast_xgb)

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print(f'MAE Error: {mean_absolute_error(test, forecast_xgb)}'), 
print(f'MAPE Error: {mean_absolute_percentage_error(test, forecast_xgb)}')
print(f'MSE Error : {error1:11.10}')
print(f'RMSE Error: {error2:11.10}')
print()
# Out:
# MAE Error: 6.535408617258072
# MAPE Error: 28.646032646818842
# MSE Error : 112.2730638
# RMSE Error: 10.59589844

# %%
test
# Out:
# 2019-06-15 00:00:00    38.94
# 2019-06-15 00:30:00    39.48
# 2019-06-15 01:00:00    38.22
# 2019-06-15 01:30:00    37.19
# 2019-06-15 02:00:00    40.13
#                        ...
# 2019-06-30 21:30:00    39.65
# 2019-06-30 22:00:00    38.50
# 2019-06-30 22:30:00    34.75
# 2019-06-30 23:00:00    34.10
# 2019-06-30 23:30:00    29.99
# Freq: 30T, Name: Price, Length: 768, dtype: float64

# %%
len(forecast_xgb)
# Out:
# 768

# %%
xgb_pred.rename('XGBoost Model Predictions').plot(legend=True)

# %%
xgb_pred
# Out:
# dt
# 2019-06-15 00:00:00    41.259490
# 2019-06-15 00:30:00    39.816010
# 2019-06-15 01:00:00    39.816010
# 2019-06-15 01:30:00    39.816010
# 2019-06-15 02:00:00    37.842598
#                          ...
# 2019-06-30 21:30:00    41.576030
# 2019-06-30 22:00:00    41.576030
# 2019-06-30 22:30:00    35.671210
# 2019-06-30 23:00:00    39.453667
# 2019-06-30 23:30:00    32.731840
# Name: predictions, Length: 768, dtype: float64
